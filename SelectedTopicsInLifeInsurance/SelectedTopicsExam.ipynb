# %% [markdown]
# # Optimization of a health insurance
#
# We consider a health insurance for disability. The insurance is activated with a single premium payment. Each year the insured, if he is disabled, receives a disability annuity of $12'000$ at the beginning of the same period.

# %% [markdown]
# ### Modeling
# #### Assumptions
#
# We assume that a person can recover in the first 7 year of disability. After 8 years the person cannot recover anymore.

# %% [markdown]
# #### Model
#
# We have a Markov chain with 8 states: $*$ (active), $\diamondsuit_{1}, \diamondsuit_{2}, \ldots, \diamondsuit_{8}$ (disabled), $\dagger$ (dead)
# The states of disability $\diamondsuit_{n}$ describe how long a person is in such state.

# %% [markdown]
# \begin{align*}
# p_{* \dagger}(x) & \quad = \quad \exp(-7.85785 + 0.01538 x + 0.000577355 x^2)\\
# p_{* \diamondsuit_{1}}(x) & \quad = \quad 3\cdot 10^{-4} \cdot (8.4764-1.0985x + 0.055x^2)\\
# p_{\diamondsuit_{k} \dagger}(x) & \quad = \quad p_{* \dagger}(x) + 0.008\\
# p_{\diamondsuit_{k} * }(x) & \quad = \quad \left \{ \array{ \exp(-0.94(k-1)) \cdot \alpha(x, k), &\text{for } k < 8 \\ 0, & \text{otherwise}} \right.\\
# \alpha(x,k) & \quad = \quad \max(0,0.773763-0.01045(x-k + 1))\\
# \end{align*}

# %% [markdown]
# \tikzset{every picture/.style={line width=0.75pt}} %set default line width to 0.75pt
#
# \begin{tikzpicture}[x=0.75pt,y=0.75pt,yscale=-1,xscale=1]
# %uncomment if require: \path (0,386); %set diagram left start at 0, and has height of 386
#
# %Shape: Rectangle [id:dp2719082123455756]
# \draw   (86,221) -- (128.8,221) -- (128.8,261) -- (86,261) -- cycle ;
# %Straight Lines [id:da3588711263904527]
# \draw    (128.8,240) -- (172.8,240) ;
# \draw [shift={(174.8,240)}, rotate = 180] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da5264667328158485]
# \draw    (107.8,171) -- (107.8,219) ;
# \draw [shift={(107.8,221)}, rotate = 270] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Shape: Rectangle [id:dp8157606177096484]
# \draw   (174,221) -- (216.8,221) -- (216.8,261) -- (174,261) -- cycle ;
# %Shape: Rectangle [id:dp1309383386293108]
# \draw   (332,221) -- (374.8,221) -- (374.8,261) -- (332,261) -- cycle ;
# %Shape: Rectangle [id:dp04525961517704058]
# \draw   (420,221) -- (462.8,221) -- (462.8,261) -- (420,261) -- cycle ;
# %Shape: Rectangle [id:dp25527895554219904]
# \draw   (86,131) -- (128.8,131) -- (128.8,171) -- (86,171) -- cycle ;
# %Straight Lines [id:da5694528187986112]
# \draw    (374.8,241) -- (398.8,241) -- (418.8,241) ;
# \draw [shift={(420.8,241)}, rotate = 180] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da3065070827642564]
# \draw    (215.8,243) -- (259.8,243) ;
# \draw [shift={(261.8,243)}, rotate = 180] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da17204801904703526]
# \draw    (285.8,243) -- (329.8,243) ;
# \draw [shift={(331.8,243)}, rotate = 180] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da7436633015215082]
# \draw    (440.8,221) -- (440.8,175) ;
# \draw [shift={(440.8,173)}, rotate = 90] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Shape: Rectangle [id:dp8849989178043702]
# \draw   (418,131) -- (460.8,131) -- (460.8,171) -- (418,171) -- cycle ;
# %Straight Lines [id:da8247440393234549]
# \draw    (65,291) -- (352.8,292) ;
# %Straight Lines [id:da9976196377939714]
# \draw    (352.6,261) -- (352.8,292) ;
# %Straight Lines [id:da2779332619436352]
# \draw    (64.8,154) -- (65,291) ;
# %Straight Lines [id:da285924392879352]
# \draw    (64.8,154) -- (83.8,154) ;
# \draw [shift={(85.8,154)}, rotate = 180] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da18268957160176136]
# \draw    (194.8,261) -- (194.8,289) ;
# \draw [shift={(194.8,291)}, rotate = 270] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da5444081373625624]
# \draw    (105.8,262) -- (105.8,290) ;
# \draw [shift={(105.8,292)}, rotate = 270] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da38018512841824403]
# \draw    (271.8,262) -- (271.8,290) ;
# \draw [shift={(271.8,292)}, rotate = 270] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da22286502595455282]
# \draw    (129,151) -- (413.8,151.99) ;
# \draw [shift={(415.8,152)}, rotate = 180.2] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da1506386142344711]
# \draw    (195,221) -- (194.81,153) ;
# \draw [shift={(194.8,151)}, rotate = 89.84] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da7780496119346232]
# \draw    (272.6,221.5) -- (272.41,153.5) ;
# \draw [shift={(272.4,151.5)}, rotate = 89.84] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Straight Lines [id:da24573933744865406]
# \draw    (353,221) -- (352.81,153) ;
# \draw [shift={(352.8,151)}, rotate = 89.84] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Curve Lines [id:da2649237918788332]
# \draw    (86,131) .. controls (83.83,91.6) and (130.37,94.89) .. (128.9,129.4) ;
# \draw [shift={(128.8,131)}, rotate = 274.76] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
# %Curve Lines [id:da7527917888197784]
# \draw    (420,261) .. controls (419.8,298.43) and (463.46,299.96) .. (462.86,262.73) ;
# \draw [shift={(462.8,261)}, rotate = 87.06] [color={rgb, 255:red, 0; green, 0; blue, 0 }  ][line width=0.75]    (10.93,-3.29) .. controls (6.95,-1.4) and (3.31,-0.3) .. (0,0) .. controls (3.31,0.3) and (6.95,1.4) .. (10.93,3.29)   ;
#
# % Text Node
# \draw (100,230) node [anchor=north west][inner sep=0.75pt]   [align=left] {$\displaystyle \diamondsuit _{1}$};
# % Text Node
# \draw (188,230) node [anchor=north west][inner sep=0.75pt]   [align=left] {$\displaystyle \diamondsuit _{2}$};
# % Text Node
# \draw (267,231) node [anchor=north west][inner sep=0.75pt]   [align=left] {...};
# % Text Node
# \draw (346,230) node [anchor=north west][inner sep=0.75pt]   [align=left] {$\displaystyle \diamondsuit _{7}$};
# % Text Node
# \draw (434,230) node [anchor=north west][inner sep=0.75pt]   [align=left] {$\displaystyle \diamondsuit _{8}$};
# % Text Node
# \draw (102,142) node [anchor=north west][inner sep=0.75pt]   [align=left] {$\displaystyle *$};
# % Text Node
# \draw (434,142) node [anchor=north west][inner sep=0.75pt]   [align=left] {$\displaystyle \dagger $};
#
#
# \end{tikzpicture}

# %% [markdown]
# ## Possible strategies
#
# 1. No action; then the above model and assumptions are used
# 2. For all active people one can reduce disability incidence rate (sigma(x)) by 17.5% (RedToInval = 0.175) for an annual cost of 150 (CostActive = 150)
# 3. For all active people with an age (< 45) one can reduce incidence rate by 70% for an annual cost of 5
# 4. For disabled people one can increase reactivation probability by 20% for a cost of 1500.

# %%
import numpy as np

# %%
class Strategy():
        
    def __init__(self):
        # Reduction of the disability incidence rate
        self.sigmareduction = 0.
        # Cost to reduce disability incidence rate
        self.costsigmareduction = 0.
        # Age limit for invalidity reduction (<)
        self.sigmareductionlimitage = 0
        # Reactivation probability increase
        self.reactivationincrease = 0.
        # Reactivation probability increase cost
        self.costreactivationincrease = 0.

    def __hash__(self):
            return hash(self.__class__)
        
    def __eq__(self, other):
             return (self.__class__ == other.__class__)
        
    # Mortality for healthy at age x
    def mua(self, x):
        return np.exp(-7.85785 + 0.01538*x + 0.000577355*x**2)

    # Mortality for disabled at age x
    def mui(self, x):
        return(self.mua(x)+0.008)

    #Probability to become disabled at age x
    def sigma(self, x):
        factor = 1
        if (x < self.sigmareductionlimitage): factor -= self.sigmareduction
        return(3.e-4 * (8.4764-1.0985*x + 0.055*x**2)) * factor
    
    def alpha(self, x,k):
        return(max(0,0.773763-0.01045*(x - k + 1)))
    # Reactivation probability for state \diamondsuit_k and age x
    def rx(self, x, k, foreversick):
        if (k>= foreversick): return(0.)
        return np.exp(-0.94*(k-1)) * self.alpha(x, k) * (1 + self.reactivationincrease)

    def stayhealty(self, x):
        return 1 - self.mua(x) - self.sigma(x)

    def staysick(self, x, status, foreversick):
        return 1 - self.mui(x) - self.rx(x, status, foreversick)    
    
    def cost(self):
        return self.costsigmareduction + self.costreactivationincrease

    @classmethod
    def noactionstrategy(cls):
        return [NoAction()]
    
    @classmethod
    def reactivation(cls):
        return [NoAction(), IncreaseReactivation()]
    
    @classmethod
    def allstrategiesforallages(cls):
        c = [cls() for cls in cls.__subclasses__()]
        c.remove(ReduceYoungDisability())
        return c
    
    @classmethod
    def allstrategies(cls):
        return [cls() for cls in cls.__subclasses__()]
    
class NoAction(Strategy):
    
    def __init__(self):
        super().__init__()
        
    def color(self):
        return "b"
    
    def description(self):
        return "No action"

# %% [markdown]
# #### Reduce disability incidence [Cost 150]
#
# \begin{align*}
# ...\\
# p_{* \diamondsuit_{1}}(x) & \quad = \quad 3\cdot 10^{-4} \cdot (8.4764-1.0985x + 0.055x^2) \color{red}{\cdot 0.825}\\
# ...
# \end{align*}
#
# #### Reduce disability for young people (< 45) [Cost 5]
# \begin{align*}
# ...\\
# p_{* \diamondsuit_{1}}(x) & \quad = \quad 3\cdot 10^{-4} \cdot (8.4764-1.0985x + 0.055x^2) \color{red}{ \cdot 0.3}\\
# ...
# \end{align*}
#
# #### Increase the probability of reactivation of sick people [Cost 1500]
# \begin{align*}
# ...\\
# p_{\diamondsuit_{k} * }(x) & \quad = \quad \left \{ \array{ \exp(-0.94(k-1)) \cdot \alpha(x, k) \color{red}{\cdot 1.2}, &\text{for } k < 8 \\ 0, & \text{otherwise}} \right.\\
# \alpha(x,k) & \quad = \quad \max(0,0.773763-0.01045(x-k + 1))\\
# ...
# \end{align*}

# %%
class ReduceDisabilityIncidence(Strategy):
    
    def __init__(self):
        super().__init__()
        # Reduction of the disability incidence rate
        self.sigmareduction = 0.175
        # Cost to reduce disability incidence rate
        self.costsigmareduction = 150.
        # Age limit for the reduction
        self.sigmareductionlimitage = 99
        
    def color(self):
        return "g"
    
    def description(self):
        return "Reduce disability"
    
    
class ReduceYoungDisability(Strategy):
    
    def __init__(self):
        super().__init__()
        # Reduce mortality
        self.sigmareduction = 0.7
        # Cost to reduce mortality
        self.costsigmareduction = 5.
        # Age limit for the reduction
        self.sigmareductionlimitage = 45

    def color(self):
        return "y"
    
    def description(self):
        return "Reduce young disability"        
        
        
class IncreaseReactivation(Strategy):
    
    def __init__(self):
        super().__init__()
        # Reactivation probability increase
        self.reactivationincrease = 0.2
        # Reactivation probability increase cost
        self.costreactivationincrease = 1500.
        
    def color(self):
        return "r"
    
    def description(self):
        return "Increase reactivation"

# %%
# Thiele's equation

class Thiele():
    
    def __init__(self, strategies):
        # Caching results
        self.stati = {}
        # Codes for the stati of the insured
        self.healthy = 0
        self.firstsick = 1
        self.foreversick = 8
        self.dead = self.foreversick + 1
        self.sicknessrange = range(1, self.dead)
        self.allrange = range(self.healthy, self.dead + 1)
        # Annual Annuity
        self.annuity = 12000.
        # Interest Rate
        self.interestrate = 0.02
        # Starting Age
        self.x0 = 25
        # End age ie last payment in period [s-1,s[ 
        self.xend = 65
        # Possible strategies
        self.strategies = strategies
        
    
    def alreadycalculated(self, n, status, strat):
        retrieved = self.stati.get(n)
        if (retrieved == None): return False
        else:
            retrieved = retrieved.get(status)
            if (retrieved == None): return False
            else: return (retrieved.get(strat) != None)
    
    def save(self, n, status, strategy, res):
        retrievedyear = self.stati.get(n)
        if (retrievedyear == None): self.stati[n] = {status: {strategy: res}}
        else: 
            retrievedstatus = retrievedyear.get(status)
            if (retrievedstatus == None): retrievedyear[status] = {strategy: res}
            else: self.stati[n][status][strategy] = res
        
    def prepayment(self, n, status, strategy):
        if (status == self.healthy or status == self.dead):
            return strategy.cost()
        elif (status in self.sicknessrange):
            return self.annuity + strategy.cost()
        else:
            raise ValueError('The status given for the prepayment is not contemplated')

    def postpayment(self, n, status, newstatus):
        return 0.

    def transitionprobability(self, n, status, newstatus, strat):
            if (status == self.healthy):
                if (newstatus == self.healthy): return strat.stayhealty(n)
                elif (newstatus == self.firstsick): return strat.sigma(n)
                elif (newstatus == self.dead): return strat.mua(n)
                else: return 0.
            elif (status in self.sicknessrange):
                if (newstatus == self.dead): return strat.mui(n)
                elif (newstatus == self.healthy): return strat.rx(n, status, self.foreversick)
                elif (newstatus == status + 1): return strat.staysick(n, status, self.foreversick)
                elif (newstatus == status == self.foreversick): return strat.staysick(n, status, self.foreversick) 
                else: return 0.
            elif (status == self.dead):
                if (newstatus == self.dead): return 1.
                else: return 0.               
            else:
                raise ValueError(f"The status {status} given for the transition probability is not contemplated")

    def reserves(self, n, status, strat):
        if (n == self.xend): return 0.
        if (status == self.dead): return 0.
        if self.alreadycalculated(n, status, strat): return self.stati[n][status][strat]
        interest = 1/(1 + self.interestrate)
        subsequent = 0
        for newstatus in range(self.dead + 1):
            tp = self.transitionprobability(n, status, newstatus, strat)
            if tp > 0:
                subsequent += tp * (self.postpayment(n, status, newstatus) + self.minreserves(n+1, newstatus))
        res = self.prepayment(n, status, strat) + interest * subsequent
        self.save(n, status, strat, res)
        return res
    
    def minreserves(self, n, status):
        return min([self.reserves(n, status, strat) for strat in self.strategies])

# %%
model = Thiele(Strategy.allstrategies())
ages = [i for i in range(model.x0, model.xend + 1)]
rsvs = [model.minreserves(j, 0) for j in ages]
rsvssick1 = [model.minreserves(j, 1) for j in ages]
rsvssick2 = [model.minreserves(j, 2) for j in ages]
rsvssick3 = [model.minreserves(j, 3) for j in ages]
rsvssick4 = [model.minreserves(j, 4) for j in ages]
rsvssick5 = [model.minreserves(j, 5) for j in ages]
rsvssick6 = [model.minreserves(j, 6) for j in ages]
rsvssick7 = [model.minreserves(j, 7) for j in ages]
rsvssick8 = [model.minreserves(j, 8) for j in ages]

# %%
import pandas as pd
import matplotlib.pyplot as plt

d={"Age": [ages[i] for i in range(0, len(ages) + 1) if i%5 == 0], 
    "active": [rsvs[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 1y": [rsvssick1[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 2y": [rsvssick2[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 3y": [rsvssick3[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 4y": [rsvssick4[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 5y": [rsvssick5[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 6y": [rsvssick6[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 7y": [rsvssick7[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "disab. 8y": [rsvssick8[i] for i in range(0, len(ages) + 1) if i%5 == 0],
  }

df = pd.DataFrame(d)
pd.set_option('precision', 0)

print(df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrr}
# \toprule
#  Age &  active &  disab. 1y &  disab. 2y &  disab. 3y &  disab. 4y &  disab. 5y &  disab. 6y &  disab. 7y &  disab. 8y \\
# \midrule
#   25 &   21686 &     100376 &     200530 &     251191 &     272467 &     280359 &     283504 &     284775 &     285294 \\
#   30 &   23282 &     109181 &     194431 &     236207 &     253479 &     259858 &     262442 &     263488 &     263917 \\
#   35 &   24586 &     115011 &     184816 &     217910 &     231294 &     236346 &     238395 &     239228 &     239571 \\
#   40 &   25472 &     116842 &     171052 &     195869 &     205606 &     209416 &     210966 &     211599 &     211862 \\
#   45 &   25893 &     112608 &     151906 &     169291 &     175869 &     178577 &     179683 &     180136 &     180326 \\
#   50 &   19749 &      99793 &     126026 &     137072 &     141423 &     143221 &     143959 &     144264 &     144393 \\
# ...

# %%
import matplotlib.pyplot as plt

path = 'Images_presentation/'

plt.plot(ages, rsvs, linewidth=0.6, marker = ".")
plt.title("Reserves at different ages of the insured (active)")
plt.xlabel("Age of the insured")
plt.ylabel("Reserves")
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(min(ages), max(ages)+1, 5))
plt.savefig(path + 'optimalreserves.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
rsvs
# Out:
# [21686.10804026805,
#  22021.44651332183,
#  22349.896439507487,
#  22670.252857319563,
#  22981.303868766026,
#  23281.840927556157,
#  23570.670182071728,
#  23846.624949900055,
#  24108.579409412734,
#  24355.46360410789,
#  24586.27986745332,
#  24800.120789527307,
#  24996.188862534505,
#  25173.817953697748,
#  25332.4988231456,
#  25471.906941745317,
#  25591.93818468354,
#  25692.761145699835,
#  25775.199476864185,
#  25840.598800934567,
#  25892.605465881446,
#  24824.101769057594,
#  23673.186432741673,
#  22441.715880384974,
#  21132.48037692222,
#  19749.33323949916,
#  18297.33940122219,
#  16782.94377250864,
#  15214.728884745919,
#  13605.468957487848,
#  11967.63764301436,
#  10316.219993541767,
#  8669.129311466484,
#  7047.701675689523,
#  5477.711118805273,
#  4000.84565463036,
#  2655.1204107657304,
#  1487.1351898917321,
#  556.1149411764704,
#  0.0,
#  0.0]

# %%
import matplotlib.patches as mpatches

model_noaction = Thiele([NoAction()])
rsvsnoaction = [model_noaction.minreserves(j, 0) for j in ages]

model_reactivationbonus = Thiele(Strategy.reactivation())
rsvsreactivationbonus = [model_reactivationbonus.minreserves(j, 0) for j in ages]

model_old = Thiele(Strategy.allstrategiesforallages())
rsvsallages = [model_old.minreserves(j, 0) for j in ages]


legend = [("blue", "No action strategy"), ("orange", "Strategy 1 + 4 (reactivation)"), ("violet", "Stragegy 1 + 2 + 4"), ("darkgreen", "All strategies")]
plt.plot(ages, rsvsnoaction, linewidth=0.6, marker = ".", color=legend[0][0])
plt.plot(ages, rsvsreactivationbonus, linewidth=0.6, marker = ".", color=legend[1][0])
plt.plot(ages, rsvsallages, linewidth=0.6, marker = ".", color=legend[2][0])
plt.plot(ages, rsvs, linewidth=0.6, marker = ".", color=legend[3][0])

handles = [mpatches.Patch(color=le[0], label=le[1]) for le in legend]
plt.legend(handles = handles, loc='upper left', bbox_to_anchor=(1, 1),
          fancybox=True, shadow=True, ncol=1)

plt.title("Reserves at different ages of the insured (active)")
plt.xlabel("Age of the insured")
plt.ylabel("Reserves")
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(min(ages), max(ages)+1, 5))

plt.savefig(path + 'comparisonstrategies.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
base = [[min(model.strategies, key = lambda strat: model.reserves(j, s, strat)) for j in ages] for s in model.allrange]

fig, ax = plt.subplots()
for s in model.allrange:
    ax.scatter(ages, [s for t in base[s]], color=[t.color() for t in base[s]])

plt.yticks(range(model.healthy - 1, model.dead + 2))
plt.xticks(np.arange(min(ages), max(ages)+1, 5))
plt.title("Optimal strategy for age and status")
plt.xlabel("Age of the insured")
plt.ylabel("Status")
handles = [mpatches.Patch(color=st.color(), label=st.description()) for st in model.strategies]
plt.legend(handles = handles, loc='upper left', bbox_to_anchor=(1, 1),
          fancybox=True, shadow=True, ncol=1)
plt.setp(ax.get_yticklabels()[0], visible=False)
plt.setp(ax.get_yticklabels()[-1], visible=False)
plt.savefig(path +'strategyapplied.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
reseverssick_1 = [model.minreserves(j, 1) for j in ages]

legend = [("blue", "active"), ("gold", "disabled 1y"), ("orange", "disabled 2y"), ("darkorange", "disabled 3y"), ("orangered", "disabled 4y"), ("red", "disabled 5y")]


plt.plot(ages, reseverssick_1, linewidth=0.6, marker = ".")
plt.title("Reserves at different ages of the insured")

plt.plot(ages, [model.minreserves(j, 0) for j in ages], linewidth=0.6, marker = ".", color=legend[0][0])
plt.plot(ages, [model.minreserves(j, 1) for j in ages], linewidth=0.6, marker = ".", color=legend[1][0])
plt.plot(ages, [model.minreserves(j, 2) for j in ages], linewidth=0.6, marker = ".", color=legend[2][0])
plt.plot(ages, [model.minreserves(j, 3) for j in ages], linewidth=0.6, marker = ".", color=legend[3][0])
plt.plot(ages, [model.minreserves(j, 4) for j in ages], linewidth=0.6, marker = ".", color=legend[4][0])
plt.plot(ages, [model.minreserves(j, 5) for j in ages], linewidth=0.6, marker = ".", color=legend[5][0])

handles = [mpatches.Patch(color=le[0], label=le[1]) for le in legend]
plt.legend(handles = handles, loc='upper left', bbox_to_anchor=(1, 1),
          fancybox=True, shadow=True, ncol=1)

plt.xlabel("Age of the insured")
plt.ylabel("Reserves")
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(min(ages), max(ages)+1, 5))
plt.savefig(path +'optimalreservesall.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
reseverssick_1 = [model.minreserves(j, 1) for j in ages]

plt.plot(ages, reseverssick_1, linewidth=0.6, marker = ".")
plt.title("Reserves at different ages of the insured (disabled 1y)")
plt.xlabel("Age of the insured")
plt.ylabel("Reserves")
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(min(ages), max(ages)+1, 5))
plt.savefig(path +'optimalreservesdisabled1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
activationprobability1 = [model.transitionprobability(a, (a - 25) % 10 + 1 , 0, base[((a - 25) % 10) + 1][a-25]) for a in ages[0:8]]
plt.scatter(ages[0:8], activationprobability1, linewidth=1.6, marker = ".")

activationprobability2 = [model.transitionprobability(b, (b - 25) % 10 + 1 , 0, base[((b - 25) % 10) + 1][b-25]) for b in ages[10:18]]
plt.scatter(ages[10:18], activationprobability2, linewidth=1.6, marker = ".")

activationprobability3 = [model.transitionprobability(a, (a - 25) % 10 + 1, 0, base[((a - 25) % 10) + 1][a-25]) for a in ages[20:28]]
plt.scatter(ages[20:28], activationprobability3, linewidth=1.6, marker = ".")

activationprobability4 = [model.transitionprobability(a, (a - 25) % 10 + 1, 0, base[((a - 25) % 10) + 1][a-25]) for a in ages[30:38]]
plt.scatter(ages[30:38], activationprobability4, linewidth=1.6, marker = ".")

plt.title("Reactivation probability for disabled (1y-8y, optimal reserving strategy)")
plt.xlabel("Age of the insured")
plt.ylabel("Probability")
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(min(ages), max(ages)+1, 5))
plt.savefig(path +'reactivationprobability.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
costs = [base[0][a - model.x0].cost() for a in ages]

strategycost = [sum(costs[(l-model.x0):]) for l in ages]

d={"Age": [ages[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "non-opt. reserves": [rsvsnoaction[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "opt. reserves": [rsvs[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "pure risk reserves": [rsvs[i] - strategycost[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "cost of strategy": [strategycost[i] for i in range(0, len(ages) + 1) if i%5 == 0],
    "% cost strategy": [strategycost[i] * 100 / max(1, rsvs[i]) for i in range(0, len(ages) + 1) if i%5 == 0],
    "% reduction": [(100 - rsvs[i] * 100 / max(1, rsvsnoaction[i])) for i in range(0, len(ages) + 1) if i%5 == 0],
  }

df = pd.DataFrame(d)
pd.set_option('precision', 0)
df["% cost strategy"] = df["% cost strategy"].map(lambda x: '{0:.2f}%'.format(x))

df["% reduction"] = df["% reduction"].map(lambda x: '{0:.2f}%'.format(x))
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrll}
# \toprule
#  Age &  non-opt. reserves &  opt. reserves &  pure risk reserves &  cost of strategy & \% cost strategy & \% reduction \\
# \midrule
#   25 &              35870 &          21686 &               18886 &              2800 &          12.91\% &      39.54\% \\
#   30 &              36923 &          23282 &               20507 &              2775 &          11.92\% &      36.94\% \\
#   35 &              36436 &          24586 &               21836 &              2750 &          11.19\% &      32.52\% \\
#   40 &              33937 &          25472 &               22747 &              2725 &          10.70\% &      24.94\% \\
#   45 &              29112 &          25893 &               23193 &              2700 &          10.43\% &      11.06\% \\
#   50 &              21960 &          19749 &               17799 &              1950 &           9.87\% &      10.07\% \\
# ...
